# %%
import tensorflow
import os
import numpy as np
import cv2

# %%
import cv2
img = cv2.imread("train/4/Training_98123.jpg")

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img.shape
# Out:
# (48, 48, 3)

# %%
Datadirectory = "train/"
